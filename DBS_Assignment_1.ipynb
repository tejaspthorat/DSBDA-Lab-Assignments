# %%
import pandas as pd

data = pd.read_csv("/content/Market.csv")

# %% [markdown]
# Preprocessing

# %% [markdown]
# Describing the data

# %%
data.head(10)
# Out:
#   Index        Date        Open        High         Low       Close  \
# 0   NYA  12/31/1965  528.690002  528.690002  528.690002  528.690002
# 1   NYA    1/3/1966  527.210022  527.210022  527.210022  527.210022
# 2   NYA    1/4/1966  527.840027  527.840027  527.840027  527.840027
# 3   NYA    1/5/1966  531.119995  531.119995  531.119995  531.119995
# 4   NYA    1/6/1966  532.070007  532.070007  532.070007  532.070007
# 5   NYA    1/7/1966  532.599976  532.599976  532.599976  532.599976
# 6   NYA   1/10/1966  533.869995  533.869995  533.869995  533.869995
# 7   NYA   1/11/1966  534.289978  534.289978  534.289978  534.289978
# 8   NYA   1/12/1966  533.340027  533.340027  533.340027  533.340027
# 9   NYA   1/13/1966  534.400024  534.400024  534.400024  534.400024
#
#     Adj Close  Volume
# 0  528.690002     0.0
# 1  527.210022     0.0
# 2  527.840027     0.0
# 3  531.119995     0.0
# 4  532.070007     0.0
# 5  532.599976     0.0
# 6  533.869995     0.0
# 7  534.289978     0.0
# ...

# %%
data.describe()
# Out:
#                 Open           High            Low          Close  \
# count  110253.000000  110252.000000  110251.000000  110250.000000
# mean     7658.561932    7704.538416    7608.129749    7657.740822
# std      9011.455529    9066.605458    8954.536718    9011.555549
# min        54.869999      54.869999      54.869999      54.869999
# 25%      1855.060059    1864.687470    1844.015015    1855.347473
# 50%      5194.399902    5226.750000    5154.299805    5194.889892
# 75%     10134.299810   10207.827635   10060.369630   10134.867430
# max     68775.062500   69403.750000   68516.992190   68775.062500
#
#            Adj Close        Volume
# count  110244.000000  1.102530e+05
# mean     7657.982529  1.273975e+09
# std      9011.723572  4.315783e+09
# min        54.869999  0.000000e+00
# 25%      1855.057556  0.000000e+00
# 50%      5195.699951  4.329000e+05
# 75%     10135.512452  1.734314e+08
# max     68775.062500  9.440374e+10

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112457 entries, 0 to 112456
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Index      112457 non-null  object
#  1   Date       112457 non-null  object
#  2   Open       110253 non-null  float64
#  3   High       110252 non-null  float64
#  4   Low        110251 non-null  float64
#  5   Close      110250 non-null  float64
#  6   Adj Close  110244 non-null  float64
#  7   Volume     110253 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 6.9+ MB

# %% [markdown]
# checking Null values

# %%
data.isna().sum()
# Out:
# Index           0
# Date            0
# Open         2204
# High         2205
# Low          2206
# Close        2207
# Adj Close    2213
# Volume       2204
# dtype: int64

# %% [markdown]
# Replacing null values with mean

# %%
data.fillna(data.mean(), inplace=True)
# Out:
# <ipython-input-46-a20208f658ce>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.fillna(data.mean(), inplace=True)

# %%
data
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0        NYA  12/31/1965   528.690002   528.690002   528.690002   528.690002
# 1        NYA    1/3/1966   527.210022   527.210022   527.210022   527.210022
# 2        NYA    1/4/1966   527.840027   527.840027   527.840027   527.840027
# 3        NYA    1/5/1966   531.119995   531.119995   531.119995   531.119995
# 4        NYA    1/6/1966   532.070007   532.070007   532.070007   532.070007
# ...      ...         ...          ...          ...          ...          ...
# 112452  N100   5/27/2021  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100   5/28/2021  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100   5/31/2021  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100    6/1/2021  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100    6/2/2021  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %%
data.isna().sum()
# Out:
# Index        0
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# Label encoding the values in the "Index" column

# %%
data['Index'].unique()
# Out:
# array(['NYA', 'IXIC', 'HSI', '000001.SS', 'GSPTSE', '399001.SZ', 'NSEI',
#        'GDAXI', 'KS11', 'SSMI', 'TWII', 'J203.JO', 'N225', 'N100'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['Index'] = le.fit_transform(data['Index'])
data
# Out:
#         Index        Date         Open         High          Low        Close  \
# 0          11  12/31/1965   528.690002   528.690002   528.690002   528.690002
# 1          11    1/3/1966   527.210022   527.210022   527.210022   527.210022
# 2          11    1/4/1966   527.840027   527.840027   527.840027   527.840027
# 3          11    1/5/1966   531.119995   531.119995   531.119995   531.119995
# 4          11    1/6/1966   532.070007   532.070007   532.070007   532.070007
# ...       ...         ...          ...          ...          ...          ...
# 112452      8   5/27/2021  1241.119995  1251.910034  1241.119995  1247.069946
# 112453      8   5/28/2021  1249.469971  1259.209961  1249.030029  1256.599976
# 112454      8   5/31/2021  1256.079956  1258.880005  1248.140015  1248.930054
# 112455      8    6/1/2021  1254.609985  1265.660034  1254.609985  1258.579956
# 112456      8    6/2/2021  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %% [markdown]
# Correcting datatype of Date

# %%
data["Date"] = pd.to_datetime(data["Date"])

# %%
data
# Out:
#         Index       Date         Open         High          Low        Close  \
# 0          11 1965-12-31   528.690002   528.690002   528.690002   528.690002
# 1          11 1966-01-03   527.210022   527.210022   527.210022   527.210022
# 2          11 1966-01-04   527.840027   527.840027   527.840027   527.840027
# 3          11 1966-01-05   531.119995   531.119995   531.119995   531.119995
# 4          11 1966-01-06   532.070007   532.070007   532.070007   532.070007
# ...       ...        ...          ...          ...          ...          ...
# 112452      8 2021-05-27  1241.119995  1251.910034  1241.119995  1247.069946
# 112453      8 2021-05-28  1249.469971  1259.209961  1249.030029  1256.599976
# 112454      8 2021-05-31  1256.079956  1258.880005  1248.140015  1248.930054
# 112455      8 2021-06-01  1254.609985  1265.660034  1254.609985  1258.579956
# 112456      8 2021-06-02  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %% [markdown]
# Using standard scalar to scale the data

# %%
from sklearn.preprocessing import StandardScaler
numeric_features = data.columns[2:]
scaler = StandardScaler()
data[numeric_features] = scaler.fit_transform(data[numeric_features])

# %%
data
# Out:
#         Index       Date      Open      High       Low     Close  Adj Close  \
# 0          11 1965-12-31 -0.799074 -0.799338 -0.798472 -0.798984  -0.799018
# 1          11 1966-01-03 -0.799239 -0.799503 -0.798639 -0.799149  -0.799183
# 2          11 1966-01-04 -0.799169 -0.799433 -0.798568 -0.799079  -0.799113
# 3          11 1966-01-05 -0.798801 -0.799067 -0.798198 -0.798711  -0.798745
# 4          11 1966-01-06 -0.798695 -0.798962 -0.798091 -0.798605  -0.798639
# ...       ...        ...       ...       ...       ...       ...        ...
# 112452      8 2021-05-27 -0.719229 -0.718777 -0.718119 -0.718472  -0.718505
# 112453      8 2021-05-28 -0.718293 -0.717963 -0.717227 -0.717404  -0.717437
# 112454      8 2021-05-31 -0.717552 -0.718000 -0.717327 -0.718263  -0.718296
# 112455      8 2021-06-01 -0.717717 -0.717245 -0.716597 -0.717182  -0.717215
# 112456      8 2021-06-02 -0.717282 -0.717462 -0.716188 -0.716617  -0.716650
#
#           Volume
# 0      -0.298127
# 1      -0.298127
# ...
